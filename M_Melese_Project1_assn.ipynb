# %% [markdown]
# ## Assignmnet 6: Regression for Numeric Data
#
# ### Author: Mahlet Melese
# ### Date: July 4, 2023

# %% [markdown]
# ## 1. Introduction
#
#
# - The primary objective of this project is to perform regression analysis on numerical data.
# - The dataset comprised of information pertaining to
# - The dataset is comprised of more than 73,000 observations, each of which pertains to a particular NY State school district and associated subgroupings/categorizations of high school students who had been enrolled for at least 4 years as of the end of the 2018-2019 school year.
# A detailed description of the attributes can be found [here.](https://data.nysed.gov/downloads.php)

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %% [markdown]
# #### Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### Read dataset from my github  repo and creat pandas dataframe

# %%
# Downloading the csv file from my GitHub repo
data_url = "https://raw.githubusercontent.com/mahletbirku/-DAV-6150/main/Project1_Data.csv" 
df = pd.read_csv(data_url, header=0)
df
# Out:
#       report_school_year  aggregation_index aggregation_type  \
# 0                2018-19                  3         District
# 1                2018-19                  3         District
# 2                2018-19                  3         District
# 3                2018-19                  3         District
# 4                2018-19                  3         District
# ...                  ...                ...              ...
# 73147            2018-19                  3         District
# 73148            2018-19                  3         District
# 73149            2018-19                  3         District
# 73150            2018-19                  3         District
# 73151            2018-19                  3         District
#
#                      aggregation_name  nrc_code                   nrc_desc  \
# 0         ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 1         ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 2         ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 3         ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# 4         ALBANY CITY SCHOOL DISTRICT         3  Urban-Suburban High Needs
# ...                               ...       ...                        ...
# 73147  DUNDEE CENTRAL SCHOOL DISTRICT         4           Rural High Needs
# 73148  DUNDEE CENTRAL SCHOOL DISTRICT         4           Rural High Needs
# 73149  DUNDEE CENTRAL SCHOOL DISTRICT         4           Rural High Needs
# 73150  DUNDEE CENTRAL SCHOOL DISTRICT         4           Rural High Needs
# 73151  DUNDEE CENTRAL SCHOOL DISTRICT         4           Rural High Needs
#
#        county_code county_name  nyc_ind  \
# 0                1      ALBANY        0
# 1                1      ALBANY        0
# 2                1      ALBANY        0
# 3                1      ALBANY        0
# 4                1      ALBANY        0
# ...            ...         ...      ...
# 73147           68       YATES        0
# 73148           68       YATES        0
# 73149           68       YATES        0
# 73150           68       YATES        0
# 73151           68       YATES        0
#
#                                         membership_desc  ...  reg_adv_cnt  \
# 0                    2013 Total Cohort - 6 Year Outcome  ...           91
# 1                    2013 Total Cohort - 6 Year Outcome  ...           47
# 2                    2013 Total Cohort - 6 Year Outcome  ...           44
# 3                    2013 Total Cohort - 6 Year Outcome  ...            -
# 4                    2013 Total Cohort - 6 Year Outcome  ...           23
# ...                                                 ...  ...          ...
# 73147  2013 Total Cohort - 6 Year Outcome - August 2019  ...            -
# 73148  2013 Total Cohort - 6 Year Outcome - August 2019  ...            -
# 73149  2013 Total Cohort - 6 Year Outcome - August 2019  ...            -
# 73150  2013 Total Cohort - 6 Year Outcome - August 2019  ...            -
# 73151  2013 Total Cohort - 6 Year Outcome - August 2019  ...            -
#
#       reg_adv_pct non_diploma_credential_cnt non_diploma_credential_pct  \
# 0             14%                         16                         2%
# 1             15%                          2                         1%
# 2             13%                         14                         4%
# 3               -                          -                          -
# 4              6%                         10                         3%
# ...           ...                        ...                        ...
# 73147           -                          -                          -
# 73148           -                          -                          -
# 73149           -                          -                          -
# 73150           -                          -                          -
# 73151           -                          -                          -
#
#       still_enr_cnt still_enr_pct ged_cnt ged_pct dropout_cnt dropout_pct
# 0                30            5%       0      0%         148         22%
# 1                11            3%       0      0%          65         20%
# 2                19            6%       0      0%          83         25%
# 3                 -             -       -       -           -           -
# 4                18            5%       0      0%          91         25%
# ...             ...           ...     ...     ...         ...         ...
# 73147             -             -       -       -           -           -
# 73148             -             -       -       -           -           -
# 73149             -             -       -       -           -           -
# 73150             -             -       -       -           -           -
# 73151             -             -       -       -           -           -
#
# [73152 rows x 29 columns]

# %% [markdown]
# **- This is the first 10 rows of the dataset using the head method. Here, we can have a first look at the features like columns and some of the values that each one takes.There are 73152 observations.**

# %% [markdown]
# #### Check the dataset shape

# %%
# check the result
df.shape
# Out:
# (73152, 29)

# %% [markdown]
# #### Data types of all columns
# - Pandas.dtypes function helps us to display the data types of all columns as a series.

# %%
# Check the data types

df.dtypes
# Out:
# report_school_year            object
# aggregation_index              int64
# aggregation_type              object
# aggregation_name              object
# nrc_code                       int64
# nrc_desc                      object
# county_code                    int64
# county_name                   object
# nyc_ind                        int64
# membership_desc               object
# subgroup_code                  int64
# subgroup_name                 object
# enroll_cnt                    object
# grad_cnt                      object
# grad_pct                      object
# local_cnt                     object
# local_pct                     object
# reg_cnt                       object
# reg_pct                       object
# reg_adv_cnt                   object
# reg_adv_pct                   object
# non_diploma_credential_cnt    object
# non_diploma_credential_pct    object
# still_enr_cnt                 object
# still_enr_pct                 object
# ged_cnt                       object
# ged_pct                       object
# dropout_cnt                   object
# dropout_pct                   object
# dtype: object

# %% [markdown]
# ## 3-4. Data Preparation and Data Review

# %% [markdown]
# ### Create a new dataframe

# %% [markdown]
# - Here, I selected features manually that deterimns the target variable 'dropout_cnt'. The chosen variables are

# %%
new_df = df[['nrc_code','county_code','subgroup_code','enroll_cnt','grad_cnt', 'local_cnt','reg_cnt','reg_adv_cnt', 'still_enr_cnt', 'dropout_cnt']].copy()

new_df
# Out:
#        nrc_code  county_code  subgroup_code enroll_cnt grad_cnt local_cnt  \
# 0             3            1              1        658      464        63
# 1             3            1              2        324      246        30
# 2             3            1              3        334      218        33
# 3             3            1              4          -        -         -
# 4             3            1              5        367      248        42
# ...         ...          ...            ...        ...      ...       ...
# 73147         4           68             18          -        -         -
# 73148         4           68             20          -        -         -
# 73149         4           68             21          -        -         -
# 73150         4           68             23          -        -         -
# 73151         4           68             25          -        -         -
#
#       reg_cnt reg_adv_cnt still_enr_cnt dropout_cnt
# 0         310          91            30         148
# 1         169          47            11          65
# 2         141          44            19          83
# 3           -           -             -           -
# 4         183          23            18          91
# ...       ...         ...           ...         ...
# 73147       -           -             -           -
# 73148       -           -             -           -
# 73149       -           -             -           -
# 73150       -           -             -           -
# 73151       -           -             -           -
#
# [73152 rows x 10 columns]

# %%
# Convert "-" to Nan
new_df = new_df.apply (pd.to_numeric, errors='coerce')
new_df
# Out:
#        nrc_code  county_code  subgroup_code  enroll_cnt  grad_cnt  local_cnt  \
# 0             3            1              1       658.0     464.0       63.0
# 1             3            1              2       324.0     246.0       30.0
# 2             3            1              3       334.0     218.0       33.0
# 3             3            1              4         NaN       NaN        NaN
# 4             3            1              5       367.0     248.0       42.0
# ...         ...          ...            ...         ...       ...        ...
# 73147         4           68             18         NaN       NaN        NaN
# 73148         4           68             20         NaN       NaN        NaN
# 73149         4           68             21         NaN       NaN        NaN
# 73150         4           68             23         NaN       NaN        NaN
# 73151         4           68             25         NaN       NaN        NaN
#
#        reg_cnt  reg_adv_cnt  still_enr_cnt  dropout_cnt
# 0        310.0         91.0           30.0        148.0
# 1        169.0         47.0           11.0         65.0
# 2        141.0         44.0           19.0         83.0
# 3          NaN          NaN            NaN          NaN
# 4        183.0         23.0           18.0         91.0
# ...        ...          ...            ...          ...
# 73147      NaN          NaN            NaN          NaN
# 73148      NaN          NaN            NaN          NaN
# 73149      NaN          NaN            NaN          NaN
# 73150      NaN          NaN            NaN          NaN
# 73151      NaN          NaN            NaN          NaN
#
# [73152 rows x 10 columns]

# %% [markdown]
# - Convert non-values into NaN so as to remove rows with those values.

# %% [markdown]
# ### Data integrity issues
#
#
# ##### Check null values
#
# - I checked null values which is a fundamental part of data cleaning. I will use Pandas. isnull() and .sum() functions together to display count of missing values of each attribute.

# %%
new_df.isnull().sum()
# Out:
# nrc_code             0
# county_code          0
# subgroup_code        0
# enroll_cnt       33478
# grad_cnt         33478
# local_cnt        33478
# reg_cnt          33478
# reg_adv_cnt      33478
# still_enr_cnt    33478
# dropout_cnt      33478
# dtype: int64

# %%
# drop Nan
new_df = new_df.dropna()
new_df
# Out:
#        nrc_code  county_code  subgroup_code  enroll_cnt  grad_cnt  local_cnt  \
# 0             3            1              1       658.0     464.0       63.0
# 1             3            1              2       324.0     246.0       30.0
# 2             3            1              3       334.0     218.0       33.0
# 4             3            1              5       367.0     248.0       42.0
# 5             3            1              6        98.0      58.0       13.0
# ...         ...          ...            ...         ...       ...        ...
# 73138         4           68              3        36.0      25.0        2.0
# 73142         4           68             10        48.0      43.0        3.0
# 73143         4           68             11        13.0       2.0        0.0
# 73145         4           68             15        33.0      23.0        0.0
# 73146         4           68             16        28.0      22.0        3.0
#
#        reg_cnt  reg_adv_cnt  still_enr_cnt  dropout_cnt
# 0        310.0         91.0           30.0        148.0
# 1        169.0         47.0           11.0         65.0
# 2        141.0         44.0           19.0         83.0
# 4        183.0         23.0           18.0         91.0
# 5         40.0          5.0            8.0         28.0
# ...        ...          ...            ...          ...
# 73138     20.0          3.0            1.0          9.0
# 73142     32.0          8.0            0.0          5.0
# 73143      2.0          0.0            2.0          6.0
# 73145     20.0          3.0            0.0          7.0
# 73146     14.0          5.0            2.0          4.0
#
# [39674 rows x 10 columns]

# %% [markdown]
# - Now we have 39674 observation with 'dropout_cnt' value.

# %%
# Check null values
new_df.isnull().sum()
# Out:
# nrc_code         0
# county_code      0
# subgroup_code    0
# enroll_cnt       0
# grad_cnt         0
# local_cnt        0
# reg_cnt          0
# reg_adv_cnt      0
# still_enr_cnt    0
# dropout_cnt      0
# dtype: int64

# %% [markdown]
# #### Let's get some of the basic statistics of the data.
#
# - From the table above, for each feature we can get the mean, standard deviation, count, and other basic information that can tell about the data.

# %%
df.describe()
# Out:
#        aggregation_index      nrc_code   county_code       nyc_ind  \
# count            73152.0  73152.000000  73152.000000  73152.000000
# mean                 3.0      4.588583     36.251859      0.055255
# std                  0.0      1.203507     20.588044      0.228479
# min                  3.0      1.000000      1.000000      0.000000
# 25%                  3.0      4.000000     17.000000      0.000000
# 50%                  3.0      5.000000     40.000000      0.000000
# 75%                  3.0      5.000000     57.000000      0.000000
# max                  3.0      6.000000     68.000000      1.000000
#
#        subgroup_code
# count   73152.000000
# mean       12.000930
# std         7.213138
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# 75%        18.000000
# max        25.000000

# %%
import seaborn as sns

sns.pairplot(new_df)

# %% [markdown]
# - From here, we can see the relationship between variables with the dependent variable- 'dropout_cnt'.

# %% [markdown]
# ## 5. Regression Model Construction & Evaluation

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# #### Build Model 1
#
# - Here, I used 5 fold cross validation, where the first fold is treated as a test set, and the model is fit on the remaining k − 1 folds.
#
# - Here, the cross_val_score from sklearn calculates the R squared metric for the applied model. R squared error close to 1 implies a better fit and less error.
#
# - Here, for the regression analysis, I used these independent variables 'subgroup_code','enroll_cnt','grad_cnt', 'local_cnt','reg_cnt','reg_adv_cnt', 'still_enr_cnt'.

# %%
x =new_df[['subgroup_code','enroll_cnt','grad_cnt', 'local_cnt','reg_cnt','reg_adv_cnt', 'still_enr_cnt']]
y = new_df['dropout_cnt']

# %%
model_1 = LinearRegression()
average_score=np.mean(cross_val_score(model_1, x, y, cv=5))
average_score
# Out:
# 0.981710403081548

# %% [markdown]
# #### Build Model 2
#
# - Here, I used 5 fold cross validation, where the first fold is treated as a test set, and the model is fit on the remaining k − 1 folds.
#
# - Here, the cross_val_score from sklearn calculates the R squared metric for the applied model. R squared error close to 1 implies a better fit and less error.
#
# - Here, for the regression analysis, I used these independent variables 'subgroup_code','enroll_cnt','grad_cnt', 'local_cnt','reg_cnt','reg_adv_cnt'.

# %%
x =new_df[['subgroup_code','enroll_cnt','grad_cnt', 'local_cnt','reg_cnt','reg_adv_cnt']]
y = new_df['dropout_cnt']

# %%
model_1 = LinearRegression()
average_score=np.mean(cross_val_score(model_1, x, y, cv=5))
average_score
# Out:
# 0.8304973148327756

# %% [markdown]
# **Conclusion, I did two multi variable linear regression models and evaluted each model using an R^2 metrics.The highest R^2 value is 0.98**

# %% [markdown]
# ### Poisson Regression Model

# %% [markdown]
# - Here, we are assuming a count data. For this, I used two independent variabes with the count data which is 'dropout_cnt'

# %%
from sklearn.linear_model import PoissonRegressor
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Model 1

# %%
p_df =new_df[['nrc_code', 'dropout_cnt']]
p_df
# Out:
#        nrc_code  dropout_cnt
# 0             3        148.0
# 1             3         65.0
# 2             3         83.0
# 4             3         91.0
# 5             3         28.0
# ...         ...          ...
# 73138         4          9.0
# 73142         4          5.0
# 73143         4          6.0
# 73145         4          7.0
# 73146         4          4.0
#
# [39674 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.set_ylabel("dropout_cnt")                                
ax.set_xlabel("nrc_code")
ax.scatter( df['nrc_code'],df['dropout_cnt'])
plt.show()

# %% [markdown]
# - Use Cross Validation

# %%
train,test=train_test_split(p_df, train_size = .8,random_state =1)

# %%
x_train=train['nrc_code'].values.reshape(-1, 1)
x_test=test['nrc_code'].values.reshape(-1, 1)
y_train=train['dropout_cnt']
y_test=test['dropout_cnt']

# %% [markdown]
# - Model training

# %%
import statsmodels.api as sm
# Fit the Poisson regression model
poisson_model = sm.GLM(y_train, x_train, family=sm.families.Poisson()).fit()
# Print the summary of the model
print(poisson_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            dropout_cnt   No. Observations:                31739
# Model:                            GLM   Df Residuals:                    31738
# Model Family:                 Poisson   Df Model:                            0
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.5250e+06
# Date:                Wed, 05 Jul 2023   Deviance:                   2.9580e+06
# Time:                        22:40:51   Pearson chi2:                 5.08e+07
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4198      0.000   1036.467      0.000       0.419       0.421
# ==============================================================================

# %%
# Predict on the test dataset
y_pred = poisson_model.predict(x_test)
score = metrics.r2_score(y_test, y_pred)
score
# Out:
# -0.08763697123053338

# %%
model = Pipeline([('model', PoissonRegressor())])
model.fit(x_train, y_train)
pred = model.predict(x_test)
score = metrics.r2_score(y_test, pred)
score
# Out:
# 0.3073467938012412

# %% [markdown]
# #### Model 2

# %%
p_df =new_df[['subgroup_code', 'dropout_cnt']]
#plot
fig, ax = plt.subplots(figsize=(20,8))
ax.set_ylabel("dropout_cnt")                                
ax.set_xlabel("subgroup_code")
ax.scatter( df['subgroup_code'],df['dropout_cnt'])
plt.show()

# %%
train,test=train_test_split(p_df, train_size = .8,random_state =1)

# %%
x_train=train['subgroup_code'].values.reshape(-1, 1)
x_test=test['subgroup_code'].values.reshape(-1, 1)
y_train=train['dropout_cnt']
y_test=test['dropout_cnt']

# %% [markdown]
# - Model training

# %%
import statsmodels.api as sm
# Fit the Poisson regression model
poisson_model = sm.GLM(y_train, x_train, family=sm.families.Poisson()).fit()
# Print the summary of the model
print(poisson_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            dropout_cnt   No. Observations:                31739
# Model:                            GLM   Df Residuals:                    31738
# Model Family:                 Poisson   Df Model:                            0
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.1579e+06
# Date:                Wed, 05 Jul 2023   Deviance:                   2.2237e+06
# Time:                        22:43:08   Pearson chi2:                 2.75e+07
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1939      0.000   1756.712      0.000       0.194       0.194
# ==============================================================================

# %%
# Predict on the test dataset
y_pred = poisson_model.predict(x_test)
score = metrics.r2_score(y_test, y_pred)
score
# Out:
# -0.03093594505953723

# %%
model = Pipeline([('model', PoissonRegressor())])
model.fit(x_train, y_train)
pred = model.predict(x_test)
score = metrics.r2_score(y_test, pred)
score
# Out:
# 0.003126848617958311

# %% [markdown]
# **Based on the information provided, I conducted two Poisson regression analyses utilizing distinct independent variables. I employed R^2 as an evaluation metric for both models. However, the outcomes yielded negative values, indicating that the data does not fully adhere to a Poisson distribution.**

# %% [markdown]
# ### Negative Binomial Regression Model

# %% [markdown]
# #### Model 1

# %%
nb_df =new_df[['nrc_code', 'dropout_cnt']]
nb_df
# Out:
#        nrc_code  dropout_cnt
# 0             3        148.0
# 1             3         65.0
# 2             3         83.0
# 4             3         91.0
# 5             3         28.0
# ...         ...          ...
# 73138         4          9.0
# 73142         4          5.0
# 73143         4          6.0
# 73145         4          7.0
# 73146         4          4.0
#
# [39674 rows x 2 columns]

# %% [markdown]
# - Cross validation

# %%
train,test=train_test_split(nb_df, train_size = .8,random_state =1)
x_train=train['nrc_code'].values.reshape(-1, 1)
x_test=test['nrc_code'].values.reshape(-1, 1)
y_train=train['dropout_cnt']
y_test=test['dropout_cnt']

# %% [markdown]
# - Model training

# %%
import statsmodels.api as sm
# Fit the regression model
nb_model = sm.GLM(y_train, x_train, family=sm.families.NegativeBinomial()).fit()
# Print the summary of the model
print(nb_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            dropout_cnt   No. Observations:                31739
# Model:                            GLM   Df Residuals:                    31738
# Model Family:        NegativeBinomial   Df Model:                            0
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -2.3444e+05
# Date:                Wed, 05 Jul 2023   Deviance:                   3.2305e+05
# Time:                        22:44:53   Pearson chi2:                 1.00e+07
# No. Iterations:                    36
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7727      0.001    633.708      0.000       0.770       0.775
# ==============================================================================

# %%
# Predict on the test dataset
y_pred = nb_model.predict(x_test)
score = metrics.r2_score(y_test, y_pred)
score
# Out:
# -1.168924865737178

# %% [markdown]
# #### Model 2

# %%
nb_df =new_df[['subgroup_code', 'dropout_cnt']]
nb_df
# Out:
#        subgroup_code  dropout_cnt
# 0                  1        148.0
# 1                  2         65.0
# 2                  3         83.0
# 4                  5         91.0
# 5                  6         28.0
# ...              ...          ...
# 73138              3          9.0
# 73142             10          5.0
# 73143             11          6.0
# 73145             15          7.0
# 73146             16          4.0
#
# [39674 rows x 2 columns]

# %%
train,test=train_test_split(nb_df, train_size = .8,random_state =1)
x_train=train['subgroup_code'].values.reshape(-1, 1)
x_test=test['subgroup_code'].values.reshape(-1, 1)
y_train=train['dropout_cnt']
y_test=test['dropout_cnt']

# %% [markdown]
# - Model training

# %%
import statsmodels.api as sm
# Fit the  regression model
nb_model = sm.GLM(y_train, x_train, family=sm.families.NegativeBinomial()).fit()
# Print the summary of the model
print(nb_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            dropout_cnt   No. Observations:                31739
# Model:                            GLM   Df Residuals:                    31738
# Model Family:        NegativeBinomial   Df Model:                            0
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.7962e+05
# Date:                Wed, 05 Jul 2023   Deviance:                   2.1341e+05
# Time:                        22:45:32   Pearson chi2:                 8.21e+06
# No. Iterations:                    13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.2728      0.001    504.672      0.000       0.272       0.274
# ==============================================================================

# %%
# Predict on the test dataset
y_pred = nb_model.predict(x_test)
score = metrics.r2_score(y_test, y_pred)
score
# Out:
# -1.7403626827576

# %% [markdown]
# - Based on the information provided, I conducted two Negative Binomial regression analyses utilizing distinct independent variables. I employed R^2 as an evaluation metric for both models. However, the outcomes yielded negative values, indicating that the data does not fully adhere to a Negative binomial distribution.

# %% [markdown]
# ## 6. Conclusions
#
# To summarize, within this project, I conducted an analysis on a publicly available dataset employing various regression models including linear, Poisson, and negative binomial models. The evaluation of these models was performed using R^2 as the assessment metric. Out of all the models, multi variable linear regression perfomed the best by having the hightest R^2 value.
